# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('ppdata\\Netflix-R\\netflix_titles.csv')

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Handling missing value

# %%
df['director'] = df['director'].fillna('Missing')

# %%
df[df['rating'].isna()]
# Out:
#      show_id     type                                              title  \
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 2359   s2360  TV Show                  Gargantia on the Verdurous Planet
# 3660   s3661  TV Show                                       Little Lunch
# 3736   s3737    Movie                                    Louis C.K. 2017
# 3737   s3738    Movie                              Louis C.K.: Hilarious
# 3738   s3739    Movie               Louis C.K.: Live at the Comedy Store
# 4323   s4324    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 67            Missing                        Oprah Winfrey, Ava DuVernay
# 2359          Missing  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 3660          Missing  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 3736       Louis C.K.                                         Louis C.K.
# ...

# %%
df['rating'].value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: rating, dtype: int64

# %%
replace_nan = {67: 'TV-PG',
               2359 :'PG-13',
               3660 : 'PG',
               3736 : 'PG-13',
               3737: 'PG-13',
               3738: 'G',
              4323: 'PG-13'}

# %%
for id, rate in replace_nan.items():
    df.iloc[id, 8] = rate

# %%
df.iloc[67,:]
# Out:
# show_id                                                       s68
# type                                                        Movie
# title           13TH: A Conversation with Oprah Winfrey & Ava ...
# director                                                  Missing
# cast                                  Oprah Winfrey, Ava DuVernay
# country                                                       NaN
# date_added                                       January 26, 2017
# release_year                                                 2017
# rating                                                      TV-PG
# duration                                                   37 min
# listed_in                                                  Movies
# description     Oprah Winfrey sits down with director Ava DuVe...
# Name: 67, dtype: object

# %%
df['country'].value_counts()
# Out:
# United States                                         2555
# India                                                  923
# United Kingdom                                         397
# Japan                                                  226
# South Korea                                            183
#                                                       ...
# Spain, Mexico, France                                    1
# United Kingdom, United States, France, Germany           1
# United Kingdom, Italy, Israel, Peru, United States       1
# India, Pakistan                                          1
# Indonesia, Netherlands                                   1
# Name: country, Length: 681, dtype: int64

# %% [raw]
# Handling the missing value of country

# %%
def country_nan(df, variable):
    frequent = df['country'].mode()[0]
    df[variable].fillna(frequent,inplace = True)

# %%
country_nan(df,'country')

# %%
df['country'].isnull().sum()
# Out:
# 0

# %%
df['cast'].fillna('Missing', inplace = True)

# %%
df['cast'].isnull().sum()
# Out:
# 0

# %%
df[df['date_added'].isna()]
# Out:
#      show_id     type                                        title director  \
# 258     s259  TV Show  A Young Doctor's Notebook and Other Stories  Missing
# 549     s550  TV Show              Anthony Bourdain: Parts Unknown  Missing
# 2263   s2264  TV Show                                      Frasier  Missing
# 2288   s2289  TV Show                                      Friends  Missing
# 2555   s2556  TV Show                              Gunslinger Girl  Missing
# 3374   s3375  TV Show                                     Kikoriki  Missing
# 3492   s3493  TV Show                          La Familia P. Luche  Missing
# 3946   s3947  TV Show                                        Maron  Missing
# 5137   s5138  TV Show                                 Red vs. Blue  Missing
# 6065   s6066  TV Show                 The Adventures of Figaro Pho  Missing
#
#                                                    cast         country  \
# ...

# %%
df['date_added'].fillna('Missing', inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df['cast'] = df['cast'].apply(lambda x : x.replace(',', ''))
df['director'] = df['director'].apply(lambda x : x.replace(',', ''))
df['listed_in'] = df['listed_in'].apply(lambda x : x.replace(',',''))
df['listed_in'] = df['listed_in'].apply(lambda x : x.replace('&',''))

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%            Missing
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel Bianca Comparato Michel Gomes Rodo...         Brazil
# 1  Demián Bichir Héctor Bonilla Oscar Serrano Aza...         Mexico
# 2  Tedd Chan Stella Chung Henley Hii Lawrence Koh...      Singapore
# 3  Elijah Wood John C. Reilly Jennifer Connelly C...  United States
# 4  Jim Sturgess Kevin Spacey Kate Bosworth Aaron ...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df['total'] = df['type'] + df['director'] + df['cast'] + df['country'] + df['rating'] + df['duration'] + df['listed_in'] + df['description']

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%            Missing
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel Bianca Comparato Michel Gomes Rodo...         Brazil
# 1  Demián Bichir Héctor Bonilla Oscar Serrano Aza...         Mexico
# 2  Tedd Chan Stella Chung Henley Hii Lawrence Koh...      Singapore
# 3  Elijah Wood John C. Reilly Jennifer Connelly C...  United States
# 4  Jim Sturgess Kevin Spacey Kate Bosworth Aaron ...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity 
from nltk.tokenize import word_tokenize

# %%
tfv = CountVectorizer()
text_features = tfv.fit_transform(df['total'])

# %%
similarity_matrix = cosine_similarity (text_features)
similarity_matrix
# Out:
# array([[1.        , 0.10375717, 0.05129892, ..., 0.13572418, 0.22041551,
#         0.16323216],
#        [0.10375717, 1.        , 0.06741999, ..., 0.15289416, 0.        ,
#         0.        ],
#        [0.05129892, 0.06741999, 1.        , ..., 0.07559289, 0.0238705 ,
#         0.02357023],
#        ...,
#        [0.13572418, 0.15289416, 0.07559289, ..., 1.        , 0.08119979,
#         0.37416574],
#        [0.22041551, 0.        , 0.0238705 , ..., 0.08119979, 1.        ,
#         0.07595545],
#        [0.16323216, 0.        , 0.02357023, ..., 0.37416574, 0.07595545,
#         1.        ]])

# %%
import random
movie_title = random.sample(list(df['title']),1)
movie_title[0]
# Out:
# 'Wild Alaska'

# %%
def recommended_movie(movie_title):
    movie_index = df[df.title == movie_title].index
    similarity_score = similarity_matrix[movie_index]
    movie_frame = pd.DataFrame(similarity_score[0],columns=['cosine_similarity'])
    movie_frame=movie_frame.reset_index()
    movie_frame = movie_frame.sort_values(by='cosine_similarity',ascending=False)
    top10 = 10 
    top10_index = list(movie_frame['index'])[:10]
    recommended_movies = {}
    for i in top10_index:
        temp = df['title'][i]
        score = movie_frame['cosine_similarity'][i]
        recommended_movies[temp]=score
    for i in recommended_movies.items():
        print(i[0])

# %%
import random
movie_title = random.sample(list(df['title']),1)
print('Movies like movie ' ,movie_title[0], 'are :')
recommended_movie(movie_title[0])
# Out:
# Movies like movie  The Witness Who Didn't See Anything are :
# The Witness Who Didn't See Anything
# Journey of an African Colony
# ARASHI's Diary -Voyage-
# Sayed the Servant
# What Did I Mess
# Chasing Cameron
# The Stranded
# Alien Worlds
# Win the Wilderness
# Africa
